# %%
from experiments import *
from visualization import *
from analysis import *

# %% [markdown]
# ## Neural entrainment

# %%
duration = 3000 # in ms
pattern = [330]

exp = Experiment(duration)
exp.create_stimuli(pattern)
exp.initialize_modules()
exp.run()
disp = Display(exp.get_results())
disp.show()

# %% [markdown]
# ## Temporal recalibration

# %%
duration = 10000
exp = Experiment(duration)
exp.initialize_multisensory(high_freq=12)
exp.run_multisensory()
disp = Display(exp.get_results(), "Temporal recalbration")
disp.show()

# %% [markdown]
# ### Visualize recalibration results

# %%
duration = 5 * 60 * 1000 # must be at least multiple minutes to get enough responses to fit
exp = Experiment(duration)
exp.initialize_multisensory(high_freq=15)
exp.run_multisensory()
tr = analyze(exp.get_trials(), plot=True)
# Out:
# temporal recalibration = 94.91491

# %% [markdown]
# ### Run recalibration analysis

# %%
compare_freqs()
# Out:
# -----
# Freq: 15
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# -----
# Freq: 20
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
